# %%
import pandas as pd
import requests
import json

# %%
headers = {"x-rapidapi-host": "imdb-top-1000-movies-series.p.rapidapi.com" ,  "x-rapidapi-key": "78a4f75f6amsh77951327de95c78p1cbec2jsnd12c260e60db" }

# %%
df = pd.DataFrame()

# %%
for i in range(1,11):
  response = requests.get( 'https://imdb-top-1000-movies-series.p.rapidapi.com/list/{}'.format(i), headers = headers)
  temp_df = pd.DataFrame(response.json()['result'])[['rank' , 'Series_Title' , 'Released_Year' ,'Runtime' , 'Genre' , 'IMDB_Rating' , 'Director' ]]
  df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#      rank              Series_Title Released_Year  Runtime  \
# 0       1  The Shawshank Redemption          1994  142 min
# 1       2             The Godfather          1972  175 min
# 2       3           The Dark Knight          2008  152 min
# 3       4    The Godfather: Part II          1974  202 min
# 4       5              12 Angry Men          1957   96 min
# ..    ...                       ...           ...      ...
# 995   996    Breakfast at Tiffany's          1961  115 min
# 996   997                     Giant          1956  201 min
# 997   998     From Here to Eternity          1953  118 min
# 998   999                  Lifeboat          1944   97 min
# 999  1000              The 39 Steps          1935   86 min
#
#                         Genre IMDB_Rating              Director
# 0                       Drama         9.3        Frank Darabont
# 1                Crime, Drama         9.2  Francis Ford Coppola
# ...

# %%
data = response.json()
json_data = json.dumps(data, indent=4)
