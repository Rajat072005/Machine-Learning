# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/imdb_top_1000.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df.sample(5)
# Out:
#                                            Poster_Link  \
# 334  https://m.media-amazon.com/images/M/MV5BZDkzMT...
# 583  https://m.media-amazon.com/images/M/MV5BMjQ0MT...
# 111  https://m.media-amazon.com/images/M/MV5BM2M1Mm...
# 688  https://m.media-amazon.com/images/M/MV5BMTQ2OD...
# 848  https://m.media-amazon.com/images/M/MV5BZGZmMW...
#
#                    Series_Title Released_Year Certificate  Runtime  \
# 334                   Gully Boy          2019          UA  154 min
# 583  Captain America: Civil War          2016          UA  147 min
# 111                 Taxi Driver          1976           A  114 min
# 688  E.T. the Extra-Terrestrial          1982           U  115 min
# 848             Blazing Saddles          1974           A   93 min
#
#                          Genre  IMDB_Rating  \
# 334      Drama, Music, Romance          8.0
# 583  Action, Adventure, Sci-Fi          7.8
# 111               Crime, Drama          8.3
# 688             Family, Sci-Fi          7.8
# 848            Comedy, Western          7.7
#
#                                               Overview  Meta_score  \
# 334  A coming-of-age story based on the lives of st...        65.0
# 583  Political involvement in the Avengers' affairs...        75.0
# 111  A mentally unstable veteran works as a nightti...        94.0
# 688  A troubled child summons the courage to help a...        91.0
# 848  In order to ruin a western town, a corrupt pol...        73.0
#
#              Director           Star1                Star2              Star3  \
# 334       Zoya Akhtar     Vijay Varma  Nakul Roshan Sahdev      Ranveer Singh
# 583     Anthony Russo       Joe Russo          Chris Evans  Robert Downey Jr.
# 111   Martin Scorsese  Robert De Niro         Jodie Foster    Cybill Shepherd
# 688  Steven Spielberg    Henry Thomas       Drew Barrymore       Peter Coyote
# 848        Mel Brooks  Cleavon Little          Gene Wilder       Slim Pickens
#
#                   Star4  No_of_Votes        Gross
# 334          Vijay Raaz        31886    5,566,534
# 583  Scarlett Johansson       663649  408,084,349
# 111       Albert Brooks       724636   28,262,574
# 688         Dee Wallace       372490  435,110,554
# 848       Harvey Korman       125993  119,500,000

# %% [markdown]
# #Categorical Data

# %% [markdown]
# a. Count Plot

# %%
sns.countplot(df['Certificate'])
# Out:
# <Axes: xlabel='count', ylabel='Certificate'>

# %% [markdown]
# b. pie chart

# %%
df['Certificate'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #Numerical data

# %% [markdown]
# a. histogram

# %%
plt.hist(df['IMDB_Rating'],bins = 10)
# Out:
# (array([280., 257., 268.,  67.,  75.,  35.,   5.,   8.,   3.,   2.]),
#  array([7.6 , 7.77, 7.94, 8.11, 8.28, 8.45, 8.62, 8.79, 8.96, 9.13, 9.3 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Released_Year'],bins=3)
# Out:
# (array([477., 377., 146.]),
#  array([ 0., 33., 66., 99.]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# b.distplot

# %%
sns.distplot(df['IMDB_Rating'])
# Out:
# /tmp/ipython-input-152525441.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['IMDB_Rating'])
# <Axes: xlabel='IMDB_Rating', ylabel='Density'>

# %% [markdown]
# c.Box Plot

# %%
sns.boxplot(df['IMDB_Rating'])
# Out:
# <Axes: ylabel='IMDB_Rating'>
